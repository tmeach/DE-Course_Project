# %%
import yfinance as yf
import pandas as pd

data = yf.download(['GOOG','META'], period='1y')

data.reset_index(inplace=True)
data
# Out:
# [*********************100%***********************]  2 of 2 completed
#           Date   Adj Close                   Close                    High  \
#                       GOOG        META        GOOG        META        GOOG
# 0   2023-03-23  106.260002  204.063492  106.260002  204.279999  107.100998
# 1   2023-03-24  106.059998  205.791641  106.059998  206.009995  106.160004
# 2   2023-03-27  103.059998  202.625015  103.059998  202.839996  105.400002
# 3   2023-03-28  101.360001  200.467300  101.360001  200.679993  103.000000
# 4   2023-03-29  101.900002  205.132355  101.900002  205.350006  102.820000
# ..         ...         ...         ...         ...         ...         ...
# 247 2024-03-18  148.479996  496.980011  148.479996  496.980011  152.929993
# 248 2024-03-19  147.919998  496.239990  147.919998  496.239990  149.619995
# 249 2024-03-20  149.679993  505.519989  149.679993  505.519989  149.759995
# 250 2024-03-21  148.740005  507.760010  148.740005  507.760010  151.304993
# ...

# %%
data.columns
# Out:
# MultiIndex([(     'Date',     ''),
#             ('Adj Close', 'GOOG'),
#             ('Adj Close', 'META'),
#             (    'Close', 'GOOG'),
#             (    'Close', 'META'),
#             (     'High', 'GOOG'),
#             (     'High', 'META'),
#             (      'Low', 'GOOG'),
#             (      'Low', 'META'),
#             (     'Open', 'GOOG'),
#             (     'Open', 'META'),
#             (   'Volume', 'GOOG'),
#             (   'Volume', 'META')],
#            )

# %%
stacked_df = data.set_index('Date').stack().reset_index()


stacked_df
# Out:
#           Date level_1   Adj Close       Close        High         Low  \
# 0   2023-03-23    GOOG  106.260002  106.260002  107.100998  105.410004
# 1   2023-03-23    META  204.063492  204.279999  207.880005  202.149994
# 2   2023-03-24    GOOG  106.059998  106.059998  106.160004  104.739998
# 3   2023-03-24    META  205.791641  206.009995  207.580002  203.550003
# 4   2023-03-27    GOOG  103.059998  103.059998  105.400002  102.629997
# ..         ...     ...         ...         ...         ...         ...
# 499 2024-03-20    META  505.519989  505.519989  508.200012  495.170013
# 500 2024-03-21    GOOG  148.740005  148.740005  151.304993  148.009995
# 501 2024-03-21    META  507.760010  507.760010  515.039978  506.010010
# 502 2024-03-22    GOOG  151.770004  151.770004  152.559998  150.089996
# 503 2024-03-22    META  509.579987  509.579987  509.970001  504.339996
#
#            Open    Volume
# 0    105.889999  31385800
# 1    202.839996  27389700
# 2    105.739998  25236200
# ...
